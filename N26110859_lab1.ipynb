# %% [markdown]
# ### 1. Implement the following layers as python functions(both forward and backward propagation)
# * Inner-product layer
# * Activation layer(Sigmoid or Rectified)
# * Softmax layer
#
# ### 2. Implement training and testing process
# * included cross-validation
#
# ### 3. Plot epoch-accuracy curves

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/AI_HW/HW1

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# load MNIST dataset 
image_size = 28           # width and length
no_of_different_labels = 10     #  i.e. 0, 1, 2, 3, ..., 9
image_pixels = image_size * image_size
train_data = np.loadtxt("mnist_train.csv", delimiter=",")
test_data = np.loadtxt("mnist_test.csv", delimiter=",") 

# data preprocessing

# map pixels information from range(0, 255) to range(0.01, 1)
fac = 0.99 / 255
train_imgs = np.asfarray(train_data[:, 1:]) * fac + 0.01
test_imgs = np.asfarray(test_data[:, 1:]) * fac + 0.01

train_labels = np.asfarray(train_data[:, :1])
test_labels = np.asfarray(test_data[:, :1])

lr = np.arange(no_of_different_labels)

# transform labels into one hot representation
train_labels_one_hot = (lr==train_labels).astype(np.float64)
test_labels_one_hot = (lr==test_labels).astype(np.float64)

# %%
x_train,x_val,y_train,y_val=train_test_split(train_imgs,train_labels_one_hot,test_size=0.2,random_state=9)

# %%
class NeuralNetwork:
    def __init__(self, X, y,val_x,val_y, batch = 120, lr = 1e-3,  epochs = 50):
        self.input = X 
        self.target = y
        self.batch = batch
        self.epochs = epochs
        self.lr = lr
        
        self.x = self.input[:self.batch] # batch input 
        self.y = self.target[:self.batch] # batch target value
        self.loss = []
        self.acc = []
        self.val_loss=[]
        self.val_acc=[]
        self.val_x=val_x
        self.val_y=val_y
        
        
        self.init_weights()

    def init_weights(self):
        self.W1 = np.random.randn(self.input.shape[1],256)
        self.W2 = np.random.randn(self.W1.shape[1],128)
        self.W3 = np.random.randn(self.W2.shape[1],self.y.shape[1])

        self.b1 = np.random.randn(self.W1.shape[1],)
        self.b2 = np.random.randn(self.W2.shape[1],)
        self.b3 = np.random.randn(self.W3.shape[1],)
    def InnerProduct_ForProp(self,x,W,b):
        y=np.dot(x,W)+b
        return y

    def InnerProduct_BackProp(self,dEdy,x,W,b):
        dEdx=np.dot(dEdy,W.T)
        dEdW=np.dot(x.T,dEdy)
        dEdb=dEdy
        return dEdx,dEdW,dEdb
    def Softmax_ForProp(self,x):
        exp=np.exp(x)
        y=exp/np.sum(exp)
        return y

    def Softmax_BackProp(self,y,t):
        dEdx=y-t
        return dEdx

    def Sigmoid_ForProp(self,x):
        y= 1/(1+np.exp(-x))
        return y

    def Sigmoid_BackProp(self,dEdy,x):
        dEdx= np.exp(-x) / np.square( 1+np.exp(-x) )
        return dEdx

        
    def ReLU(self, x):
        return np.maximum(0,x)

    def dReLU(self,x):
        return 1 * (x > 0) 
    
    def softmax(self, z):
        z = z - np.max(z, axis = 1).reshape(z.shape[0],1)
        return np.exp(z) / np.sum(np.exp(z), axis = 1).reshape(z.shape[0],1)
    
    def shuffle(self):
        idx = [i for i in range(self.input.shape[0])]
        np.random.shuffle(idx)
        self.input = self.input[idx]
        self.target = self.target[idx]
        
    def feedforward(self):

        ## innper product
        self.z1 = self.x.dot(self.W1) + self.b1
        self.a1 = self.ReLU(self.z1)

        self.z2 = self.a1.dot(self.W2) + self.b2
        self.a2 = self.ReLU(self.z2)

        self.z3 = self.a2.dot(self.W3) + self.b3
        self.a3 = self.softmax(self.z3)
        self.error = self.a3 - self.y

        
    def backprop(self):
        dcost = (1/self.batch)*self.error
        
        DW3 = np.dot(dcost.T,self.a2).T
        DW2 = np.dot((np.dot((dcost),self.W3.T) * self.dReLU(self.z2)).T,self.a1).T
        DW1 = np.dot((np.dot(np.dot((dcost),self.W3.T)*self.dReLU(self.z2),self.W2.T)*self.dReLU(self.z1)).T,self.x).T

        db3 = np.sum(dcost,axis = 0)
        db2 = np.sum(np.dot((dcost),self.W3.T) * self.dReLU(self.z2),axis = 0)
        db1 = np.sum((np.dot(np.dot((dcost),self.W3.T)*self.dReLU(self.z2),self.W2.T)*self.dReLU(self.z1)),axis = 0)
        
        self.W3 = self.W3 - self.lr * DW3
        self.W2 = self.W2 - self.lr * DW2
        self.W1 = self.W1 - self.lr * DW1
        
        self.b3 = self.b3 - self.lr * db3
        self.b2 = self.b2 - self.lr * db2
        self.b1 = self.b1 - self.lr * db1
    def train(self):
        for epoch in range(self.epochs):
            l = 0
            acc = 0
            self.shuffle()
            for batch in range(self.input.shape[0]//self.batch-1):
                start = batch*self.batch
                end = (batch+1)*self.batch
                self.x = self.input[start:end]
                self.y = self.target[start:end]
                self.feedforward()
                self.backprop()
                l+=np.mean(self.error**2)
                criterion=nn.CrossEntropyLoss()
                #l+=criterion(self.a3,self.y)
                acc+= np.count_nonzero(np.argmax(self.a3,axis=1) == np.argmax(self.y,axis=1)) / self.batch
            
            # calculate validation loss accuracy
            self.x=self.val_x
            self.y=self.val_y
            val_size=self.y.shape[0]
            self.feedforward()

            self.val_loss.append(np.mean(self.error**2))
            val_acc=(np.count_nonzero(np.argmax(self.a3,axis=1) == np.argmax(self.y,axis=1)) / val_size)*100
            self.val_acc.append(val_acc)
            # training loss accuarcy
            self.loss.append(l/(self.input.shape[0]//self.batch))
            self.acc.append(acc*100/(self.input.shape[0]//self.batch))
            print("epochs:",epoch+1)
            print("training loss:",self.loss[-1])
            print("training accuracy:",self.acc[-1])
            print("validation loss:",self.val_loss[-1])
            print("validation accuracy",self.val_acc[-1])
            print("----------------------------")
            
    def loss_plot(self):
        plt.figure(dpi = 125)
        line1,=plt.plot(self.loss,"b-",label="train")
        line2,=plt.plot(self.val_loss,"y-",label="val")
        plt.legend(handles=[line1,line2])
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
    
    def acc_plot(self):
        plt.figure(dpi = 125)
        line1,=plt.plot(self.acc,"b-",label="train")
        line2,=plt.plot(self.val_acc,"y-",label="val")
        plt.legend(handles=[line1,line2])
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        
    def test(self,xtest,ytest):
        self.x = xtest
        self.y = ytest
        self.feedforward()
        acc = np.count_nonzero(np.argmax(self.a3,axis=1) == np.argmax(self.y,axis=1)) / self.x.shape[0]
        print("Accuracy:", 100 * acc, "%")

# %%
NN = NeuralNetwork(x_train, y_train,x_val,y_val) 
NN.train()
#NN.plot()
#NN.test(X_test,y_test)
# Out:
# epochs: 1
# training loss: 0.07959162018369714
# training accuracy: 59.818750000000016
# validation loss: 0.05215296847759641
# validation accuracy 73.81666666666666
# ----------------------------
# epochs: 2
# training loss: 0.04455843219878339
# training accuracy: 77.33958333333338
# validation loss: 0.041460635382282694
# validation accuracy 79.16666666666666
# ----------------------------
# epochs: 3
# training loss: 0.03721628337265972
# training accuracy: 81.03750000000005
# validation loss: 0.03593005533129551
# validation accuracy 81.925
# ----------------------------
# epochs: 4
# training loss: 0.033293022508301774
# training accuracy: 82.98541666666664
# validation loss: 0.03354748002157212
# validation accuracy 83.125
# ----------------------------
# epochs: 5
# training loss: 0.031028476286572893
# training accuracy: 84.11666666666665
# validation loss: 0.031914386252653214
# validation accuracy 83.91666666666666
# ----------------------------
# epochs: 6
# training loss: 0.029293651441816927
# training accuracy: 84.96041666666662
# validation loss: 0.02997398661966614
# validation accuracy 84.86666666666667
# ----------------------------
# epochs: 7
# training loss: 0.02778780242495135
# training accuracy: 85.75208333333322
# validation loss: 0.02912205356360629
# validation accuracy 85.34166666666667
# ----------------------------
# epochs: 8
# training loss: 0.026714496345603123
# training accuracy: 86.2583333333333
# validation loss: 0.0283091659153983
# validation accuracy 85.7
# ----------------------------
# epochs: 9
# training loss: 0.02573513412706593
# training accuracy: 86.76041666666663
# validation loss: 0.02797543857237477
# validation accuracy 85.86666666666667
# ----------------------------
# epochs: 10
# training loss: 0.02508084981804773
# training accuracy: 87.05833333333335
# validation loss: 0.02710385982965218
# validation accuracy 86.325
# ----------------------------
# epochs: 11
# training loss: 0.02437564703534391
# training accuracy: 87.40625000000011
# validation loss: 0.02701572234581602
# validation accuracy 86.35833333333333
# ----------------------------
# epochs: 12
# training loss: 0.023771629938969297
# training accuracy: 87.71458333333327
# validation loss: 0.026513318430461015
# validation accuracy 86.6
# ----------------------------
# epochs: 13
# training loss: 0.023300750224159943
# training accuracy: 87.93750000000009
# validation loss: 0.026008080281038792
# validation accuracy 86.85833333333333
# ----------------------------
# epochs: 14
# training loss: 0.022873833965957643
# training accuracy: 88.13333333333341
# validation loss: 0.025802583912937892
# validation accuracy 86.925
# ----------------------------
# epochs: 15
# training loss: 0.022300262112585355
# training accuracy: 88.44166666666668
# validation loss: 0.02557294558325507
# validation accuracy 87.04166666666666
# ----------------------------
# epochs: 16
# training loss: 0.021943253228183347
# training accuracy: 88.61458333333341
# validation loss: 0.025092462917055205
# validation accuracy 87.25833333333334
# ----------------------------
# epochs: 17
# training loss: 0.021724987355854555
# training accuracy: 88.69375000000008
# validation loss: 0.02490430374510031
# validation accuracy 87.375
# ----------------------------
# epochs: 18
# training loss: 0.02140768926080223
# training accuracy: 88.8541666666667
# validation loss: 0.024849979165822343
# validation accuracy 87.41666666666667
# ----------------------------
# epochs: 19
# training loss: 0.021170772662890774
# training accuracy: 88.96041666666662
# validation loss: 0.024888804136382604
# validation accuracy 87.33333333333333
# ----------------------------
# epochs: 20
# training loss: 0.020611805973756975
# training accuracy: 89.25208333333336
# validation loss: 0.02455493270744146
# validation accuracy 87.56666666666668
# ----------------------------
# epochs: 21
# training loss: 0.02066569351977462
# training accuracy: 89.21666666666678
# validation loss: 0.024344942810704342
# validation accuracy 87.65833333333333
# ----------------------------
# epochs: 22
# training loss: 0.02018499830580174
# training accuracy: 89.4145833333335
# validation loss: 0.02405093038621275
# validation accuracy 87.8
# ----------------------------
# epochs: 23
# training loss: 0.019971341381559312
# training accuracy: 89.55208333333341
# validation loss: 0.023653587958357123
# validation accuracy 87.94999999999999
# ----------------------------
# epochs: 24
# training loss: 0.019756964094720622
# training accuracy: 89.63750000000009
# validation loss: 0.023628979772438392
# validation accuracy 88.03333333333333
# ----------------------------
# epochs: 25
# training loss: 0.019425494018333867
# training accuracy: 89.8041666666667
# validation loss: 0.02371345305739102
# validation accuracy 87.90833333333333
# ----------------------------
# epochs: 26
# training loss: 0.019383780302100983
# training accuracy: 89.81666666666675
# validation loss: 0.023530526339756438
# validation accuracy 88.03333333333333
# ----------------------------
# epochs: 27
# training loss: 0.019154879684032074
# training accuracy: 89.94791666666683
# validation loss: 0.02344620836796029
# validation accuracy 88.09166666666667
# ----------------------------
# epochs: 28
# training loss: 0.018956282583930468
# training accuracy: 90.03125000000004
# validation loss: 0.02365130291474388
# validation accuracy 87.96666666666667
# ----------------------------
# epochs: 29
# training loss: 0.018948601769238578
# training accuracy: 90.01875000000014
# validation loss: 0.023016967901550636
# validation accuracy 88.30833333333334
# ----------------------------
# epochs: 30
# training loss: 0.01879628869764608
# training accuracy: 90.10208333333338
# validation loss: 0.023127249364918438
# validation accuracy 88.23333333333333
# ----------------------------
# epochs: 31
# training loss: 0.018549205216344917
# training accuracy: 90.24166666666677
# validation loss: 0.02333391092627555
# validation accuracy 88.14166666666667
# ----------------------------
# epochs: 32
# training loss: 0.01851863534282899
# training accuracy: 90.2437500000001
# validation loss: 0.023116618974231614
# validation accuracy 88.23333333333333
# ----------------------------
# epochs: 33
# training loss: 0.018191158018820555
# training accuracy: 90.38124999999998
# validation loss: 0.022702383255020782
# validation accuracy 88.425
# ----------------------------
# epochs: 34
# training loss: 0.01810281565975782
# training accuracy: 90.42708333333354
# validation loss: 0.022728783510001856
# validation accuracy 88.41666666666667
# ----------------------------
# epochs: 35
# training loss: 0.018030664266036875
# training accuracy: 90.43750000000013
# validation loss: 0.02263803853774092
# validation accuracy 88.44166666666666
# ----------------------------
# epochs: 36
# training loss: 0.017920982527489977
# training accuracy: 90.49166666666677
# validation loss: 0.022587911684161455
# validation accuracy 88.44166666666666
# ----------------------------
# epochs: 37
# training loss: 0.01799330809560509
# training accuracy: 90.45833333333347
# validation loss: 0.023070524855698903
# validation accuracy 88.20833333333333
# ----------------------------
# epochs: 38
# training loss: 0.01765646791385526
# training accuracy: 90.62708333333347
# validation loss: 0.022442420248355938
# validation accuracy 88.50833333333334
# ----------------------------
# epochs: 39
# training loss: 0.01770443656444337
# training accuracy: 90.56875
# validation loss: 0.022475609098618354
# validation accuracy 88.49166666666667
# ----------------------------
# epochs: 40
# training loss: 0.017631251397624816
# training accuracy: 90.60208333333338
# validation loss: 0.022644681300989112
# validation accuracy 88.43333333333334
# ----------------------------
# epochs: 41
# training loss: 0.01748811600956137
# training accuracy: 90.68750000000009
# validation loss: 0.022665491022933682
# validation accuracy 88.43333333333334
# ----------------------------
# epochs: 42
# training loss: 0.017335089284282387
# training accuracy: 90.75416666666678
# validation loss: 0.02249566970762265
# validation accuracy 88.46666666666667
# ----------------------------
# epochs: 43
# training loss: 0.017207013091885718
# training accuracy: 90.79791666666677
# validation loss: 0.022263336275272855
# validation accuracy 88.54166666666666
# ----------------------------
# epochs: 44
# training loss: 0.017286995980842032
# training accuracy: 90.76875000000013
# validation loss: 0.022080968199260326
# validation accuracy 88.66666666666667
# ----------------------------
# epochs: 45
# training loss: 0.017216346280668905
# training accuracy: 90.78541666666668
# validation loss: 0.022498290153813424
# validation accuracy 88.425
# ----------------------------
# epochs: 46
# training loss: 0.01703149673671334
# training accuracy: 90.87083333333348
# validation loss: 0.022059792764259588
# validation accuracy 88.66666666666667
# ----------------------------
# epochs: 47
# training loss: 0.016954889470108456
# training accuracy: 90.8875000000001
# validation loss: 0.022343351016491375
# validation accuracy 88.49166666666667
# ----------------------------
# epochs: 48
# training loss: 0.01687786342395972
# training accuracy: 90.95208333333345
# validation loss: 0.02214457446902237
# validation accuracy 88.575
# ----------------------------
# epochs: 49
# training loss: 0.01682401712177429
# training accuracy: 90.97083333333329
# validation loss: 0.021746756288113837
# validation accuracy 88.79166666666667
# ----------------------------
# epochs: 50
# training loss: 0.016764102762254932
# training accuracy: 90.9812500000001
# validation loss: 0.02210110820420652
# validation accuracy 88.625
# ----------------------------

# %%
NN.acc_plot()
NN.loss_plot()

# %%
print(NN.val_acc[-1])
# Out:
# 88.625
